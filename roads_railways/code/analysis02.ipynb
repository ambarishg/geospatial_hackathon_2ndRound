# %%
# !pip install odc-stac
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting odc-stac
#   Downloading odc_stac-0.3.5-py3-none-any.whl (55 kB)
#      ---------------------------------------- 55.9/55.9 kB 1.4 MB/s eta 0:00:00
# Requirement already satisfied: pandas in c:\applications\anaconda\lib\site-packages (from odc-stac) (1.4.4)
# Requirement already satisfied: dask[array] in c:\applications\anaconda\lib\site-packages (from odc-stac) (2022.7.0)
# Collecting affine
#   Downloading affine-2.3.1-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: numpy>=1.20.0 in c:\applications\anaconda\lib\site-packages (from odc-stac) (1.21.5)
# Collecting rasterio!=1.3.0,!=1.3.1,>=1.0.0
#   Downloading rasterio-1.3.4-cp39-cp39-win_amd64.whl (22.2 MB)
#      --------------------------------------- 22.2/22.2 MB 12.6 MB/s eta 0:00:00
# Requirement already satisfied: toolz in c:\applications\anaconda\lib\site-packages (from odc-stac) (0.11.2)
# Requirement already satisfied: xarray>=0.19 in c:\applications\anaconda\lib\site-packages (from odc-stac) (0.20.1)
# Collecting pystac<2,>=1.0.0
#   Downloading pystac-1.6.1-py3-none-any.whl (146 kB)
#      -------------------------------------- 146.0/146.0 kB 8.5 MB/s eta 0:00:00
# Collecting odc-geo>=0.3.0
#   Downloading odc_geo-0.3.3-py3-none-any.whl (114 kB)
#      ---------------------------------------- 114.4/114.4 kB ? eta 0:00:00
# Requirement already satisfied: shapely in c:\users\ambar\appdata\roaming\python\python39\site-packages (from odc-geo>=0.3.0->odc-stac) (2.0.0)
# Requirement already satisfied: cachetools in c:\users\ambar\appdata\roaming\python\python39\site-packages (from odc-geo>=0.3.0->odc-stac) (5.2.0)
# Requirement already satisfied: pyproj>=3.0.0 in c:\users\ambar\appdata\roaming\python\python39\site-packages (from odc-geo>=0.3.0->odc-stac) (3.4.1)
# Requirement already satisfied: python-dateutil>=2.7.0 in c:\applications\anaconda\lib\site-packages (from pystac<2,>=1.0.0->odc-stac) (2.8.2)
# Requirement already satisfied: attrs in c:\applications\anaconda\lib\site-packages (from rasterio!=1.3.0,!=1.3.1,>=1.0.0->odc-stac) (21.4.0)
# Collecting snuggs>=1.4.1
#   Downloading snuggs-1.4.7-py3-none-any.whl (5.4 kB)
# Requirement already satisfied: click-plugins in c:\users\ambar\appdata\roaming\python\python39\site-packages (from rasterio!=1.3.0,!=1.3.1,>=1.0.0->odc-stac) (1.1.1)
# Requirement already satisfied: certifi in c:\applications\anaconda\lib\site-packages (from rasterio!=1.3.0,!=1.3.1,>=1.0.0->odc-stac) (2022.9.14)
# Requirement already satisfied: setuptools in c:\applications\anaconda\lib\site-packages (from rasterio!=1.3.0,!=1.3.1,>=1.0.0->odc-stac) (63.4.1)
# Requirement already satisfied: click>=4.0 in c:\applications\anaconda\lib\site-packages (from rasterio!=1.3.0,!=1.3.1,>=1.0.0->odc-stac) (8.0.4)
# Requirement already satisfied: cligj>=0.5 in c:\users\ambar\appdata\roaming\python\python39\site-packages (from rasterio!=1.3.0,!=1.3.1,>=1.0.0->odc-stac) (0.7.2)
# Requirement already satisfied: pytz>=2020.1 in c:\applications\anaconda\lib\site-packages (from pandas->odc-stac) (2022.1)
# Requirement already satisfied: packaging>=20.0 in c:\applications\anaconda\lib\site-packages (from dask[array]->odc-stac) (21.3)
# Requirement already satisfied: cloudpickle>=1.1.1 in c:\applications\anaconda\lib\site-packages (from dask[array]->odc-stac) (2.0.0)
# Requirement already satisfied: fsspec>=0.6.0 in c:\applications\anaconda\lib\site-packages (from dask[array]->odc-stac) (2022.7.1)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\applications\anaconda\lib\site-packages (from dask[array]->odc-stac) (6.0)
# Requirement already satisfied: partd>=0.3.10 in c:\applications\anaconda\lib\site-packages (from dask[array]->odc-stac) (1.2.0)
# Requirement already satisfied: colorama in c:\applications\anaconda\lib\site-packages (from click>=4.0->rasterio!=1.3.0,!=1.3.1,>=1.0.0->odc-stac) (0.4.5)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\applications\anaconda\lib\site-packages (from packaging>=20.0->dask[array]->odc-stac) (3.0.9)
# Requirement already satisfied: locket in c:\applications\anaconda\lib\site-packages (from partd>=0.3.10->dask[array]->odc-stac) (1.0.0)
# Requirement already satisfied: six>=1.5 in c:\applications\anaconda\lib\site-packages (from python-dateutil>=2.7.0->pystac<2,>=1.0.0->odc-stac) (1.16.0)
# Installing collected packages: affine, snuggs, pystac, odc-geo, rasterio, odc-stac
# Successfully installed affine-2.3.1 odc-geo-0.3.3 odc-stac-0.3.5 pystac-1.6.1 rasterio-1.3.4 snuggs-1.4.7

# %%
import odc.stac

# %%
# !pip install planetary-computer
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting planetary-computer
#   Downloading planetary_computer-0.4.9-py3-none-any.whl (17 kB)
# Collecting pystac-client>=0.2.0
#   Downloading pystac_client-0.5.1-py3-none-any.whl (29 kB)
# Requirement already satisfied: requests>=2.25.1 in c:\applications\anaconda\lib\site-packages (from planetary-computer) (2.28.1)
# Requirement already satisfied: pytz>=2020.5 in c:\applications\anaconda\lib\site-packages (from planetary-computer) (2022.1)
# Requirement already satisfied: click>=7.1 in c:\applications\anaconda\lib\site-packages (from planetary-computer) (8.0.4)
# Collecting pydantic[dotenv]>=1.7.3
#   Downloading pydantic-1.10.4-cp39-cp39-win_amd64.whl (2.1 MB)
#      ---------------------------------------- 2.1/2.1 MB 10.5 MB/s eta 0:00:00
# Requirement already satisfied: pystac>=1.0.0 in c:\users\ambar\appdata\roaming\python\python39\site-packages (from planetary-computer) (1.6.1)
# Requirement already satisfied: colorama in c:\applications\anaconda\lib\site-packages (from click>=7.1->planetary-computer) (0.4.5)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\applications\anaconda\lib\site-packages (from pydantic[dotenv]>=1.7.3->planetary-computer) (4.3.0)
# Collecting python-dotenv>=0.10.4
#   Using cached python_dotenv-0.21.0-py3-none-any.whl (18 kB)
# Requirement already satisfied: python-dateutil>=2.7.0 in c:\applications\anaconda\lib\site-packages (from pystac>=1.0.0->planetary-computer) (2.8.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\applications\anaconda\lib\site-packages (from requests>=2.25.1->planetary-computer) (2022.9.14)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\applications\anaconda\lib\site-packages (from requests>=2.25.1->planetary-computer) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\applications\anaconda\lib\site-packages (from requests>=2.25.1->planetary-computer) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\applications\anaconda\lib\site-packages (from requests>=2.25.1->planetary-computer) (1.26.11)
# Requirement already satisfied: six>=1.5 in c:\applications\anaconda\lib\site-packages (from python-dateutil>=2.7.0->pystac>=1.0.0->planetary-computer) (1.16.0)
# Installing collected packages: python-dotenv, pydantic, pystac-client, planetary-computer
# Successfully installed planetary-computer-0.4.9 pydantic-1.10.4 pystac-client-0.5.1 python-dotenv-0.21.0

# %%
import planetary_computer as pc
from pystac_client import Client

# %%
catalog = Client.open(
    "https://planetarycomputer.microsoft.com/api/stac/v1", modifier=pc.sign_inplace
)

# %%
catalog
# Out:
# <Client id=microsoft-pc>
