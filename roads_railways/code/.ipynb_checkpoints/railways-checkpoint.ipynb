# %%
SHAPE_FILE_ROADS = '../input/roads_railways/gis_osm_roads_free_1.shp'
FILE2 = '../input/village_census/india-village-census-2001-WB.shp'

# %%
import geopandas as gpd

# %%
# %%time
plot_locations = gpd.read_file(SHAPE_FILE_ROADS)
# Out:
# Wall time: 2min 34s

# %%
len(plot_locations)
# Out:
# 2111685

# %%
plot_locations.head()
# Out:
#     osm_id  code    fclass                    name   ref oneway  maxspeed  \
# 0  3187224  5115  tertiary                Sha Road  None      B         0
# 1  3191425  5115  tertiary                      U2  None      B         0
# 2  3191428  5115  tertiary  Transport Bustand Road  None      B         0
# 3  3191437  5115  tertiary           Housing Board  None      B         0
# 4  3194810  5115  tertiary             Market Road  None      B         0
#
#    layer bridge tunnel                                           geometry
# 0      0      F      F  LINESTRING (76.32194 10.30471, 76.32174 10.304...
# 1      0      F      F  LINESTRING (76.33476 10.30725, 76.33477 10.306...
# 2      0      F      F  LINESTRING (76.33261 10.29997, 76.33282 10.300...
# 3      0      F      F  LINESTRING (76.33261 10.29997, 76.33327 10.299...
# 4      0      F      F  LINESTRING (76.33898 10.30246, 76.33906 10.305...

# %%
plot_locations[plot_locations.code == 5154]
# Out:
#             osm_id  code fclass                  name   ref oneway  maxspeed  \
# 1848      22836390  5154   path                  None  None      B         0
# 2743      22843941  5154   path  Jethalal Parekh Road  None      B         0
# 2898      22846167  5154   path                  None  None      B         0
# 2916      22846331  5154   path                  None  None      B         0
# 5104      22871593  5154   path                  None  None      B         0
# ...            ...   ...    ...                   ...   ...    ...       ...
# 2111546  585164269  5154   path                  None  None      B         0
# 2111628  585204823  5154   path                  None  None      B         0
# 2111629  585204824  5154   path                  None  None      B         0
# 2111630  585204825  5154   path                  None  None      B         0
# 2111632  585204827  5154   path                  None  None      B         0
#
#          layer bridge tunnel  \
# 1848         0      F      F
# 2743         0      F      F
# 2898         0      F      F
# 2916         0      F      F
# 5104         0      F      F
# ...        ...    ...    ...
# 2111546      0      F      F
# 2111628      0      F      F
# 2111629      0      F      F
# 2111630      0      F      F
# 2111632      0      F      F
#
#                                                   geometry
# 1848     LINESTRING (77.70280 35.18310, 77.70950 35.200...
# 2743     LINESTRING (72.90661 19.08313, 72.90731 19.08349)
# 2898     LINESTRING (72.83072 18.91688, 72.83042 18.917...
# 2916     LINESTRING (72.83038 18.91418, 72.83029 18.914...
# 5104     LINESTRING (75.86216 30.85492, 75.86245 30.854...
# ...                                                    ...
# 2111546  LINESTRING (91.71659 26.12800, 91.71652 26.127...
# 2111628  LINESTRING (77.17720 32.30911, 77.17715 32.309...
# 2111629  LINESTRING (77.17733 32.30925, 77.17739 32.309...
# 2111630  LINESTRING (77.17678 32.30907, 77.17679 32.309...
# 2111632  LINESTRING (77.17743 32.30862, 77.17755 32.308...
#
# [38625 rows x 11 columns]

# %%
assam = gpd.read_file(FILE2)

# %%
len(assam)
# Out:
# 41319

# %%
assam.head()
# Out:
#   SID DID   TID VILL_CODE          C_CODE01                         NAME  \
# 0  19  01  0001  00000100  1901000100000100             Singalila Forest
# 1  19  01  0004  00013000  1901000400013000            Kashone Khasmahal
# 2  19  01  0004  00012900  1901000400012900  Mansong Cinchona Plantation
# 3  19  01  0004  00012700  1901000400012700                Rangpo Forest
# 4  19  01  0004  00013700  1901000400013700            Lingsay Khasmahal
#
#       UID    CENSUS_COD  STATE  DISTRICT  ...  TANK_IRR  RIVER_IRR  LAKE_IRR  \
# 0  284099  1.901000e+15     19         1  ...         0          0         0
# 1  284100  1.901000e+15     19         1  ...         0          0         0
# 2  284101  1.901000e+15     19         1  ...         0          0         0
# 3  284102  1.901000e+15     19         1  ...         0          0         0
# 4  284103  1.901000e+15     19         1  ...         0          0         0
#
#    W_FALL OTH_IRR TOT_IRR  UN_IRR  CULT_WASTE  AREA_NA_CU  \
# 0       0    0.00    0.00    0.00        0.00       72.86
# 1       0    0.00    0.00  287.33        0.00      804.12
# 2       0   17.38   17.38  490.00       20.69      246.75
# 3       0    0.00    0.00   48.28       22.45      108.94
# 4       0    0.00  231.52  231.52      123.01      411.17
#
#                                             geometry
# 0  POLYGON ((1202154.354 3028168.507, 1202151.006...
# 1  POLYGON ((1251641.777 3029997.867, 1251681.079...
# 2  POLYGON ((1250481.692 3029651.429, 1250614.649...
# 3  POLYGON ((1250481.692 3029651.429, 1250496.055...
# 4  POLYGON ((1264036.297 3026085.213, 1264012.597...
#
# [5 rows x 214 columns]

# %%
polygon = assam.geometry.unary_union

# %%
polygon
# Out:
# <MULTIPOLYGON (((1030858.538 2555155.587, 1030694.168 2555177.554, 1030570.1...>

# %%
motorway = plot_locations[plot_locations.fclass == 'motorway']

# %%
len(motorway)
# Out:
# 2544

# %%
x = plot_locations.to_crs(epsg='4326')
y = assam.to_crs(epsg='4326')

# %%
mx = y.overlay(x,how="intersection",keep_geom_type=False)

# %%
mx
# Out:
#        SID DID   TID VILL_CODE          C_CODE01              NAME     UID  \
# 0       19  01  0001  00000100  1901000100000100  Singalila Forest  284099
# 1       19  01  0001  00000100  1901000100000100  Singalila Forest  284099
# 2       19  01  0001  00000100  1901000100000100  Singalila Forest  284099
# 3       19  01  0001  00000200  1901000100000200           Rimbick  284111
# 4       19  01  0001  00000100  1901000100000100  Singalila Forest  284099
# ...     ..  ..   ...       ...               ...               ...     ...
# 122758  19  18  0028  04068800  1918002804068800     Fedric Island  325414
# 122759  19  18  0028  04068200  1918002804068200          Amrabati  325413
# 122760  19  18  0028  04068300  1918002804068300   Lakshmipur Abad  325416
# 122761  19  18  0028  04068200  1918002804068200          Amrabati  325413
# 122762  19  18  0024      None              None            Island  325083
#
#           CENSUS_COD  STATE  DISTRICT  ...  code        fclass  name      ref  \
# 0       1.901000e+15     19         1  ...  5154          path  None     None
# 1       1.901000e+15     19         1  ...  5145  track_grade3  None     None
# 2       1.901000e+15     19         1  ...  5154          path  None     None
# 3       1.901000e+15     19         1  ...  5154          path  None     None
# 4       1.901000e+15     19         1  ...  5121  unclassified  None  02DR009
# ...              ...    ...       ...  ...   ...           ...   ...      ...
# 122758  1.918000e+15     19        18  ...  5113       primary  None     None
# 122759  1.918000e+15     19        18  ...  5115      tertiary  None     None
# 122760  1.918000e+15     19        18  ...  5115      tertiary  None     None
# 122761  1.918000e+15     19        18  ...  5141       service  None     None
# 122762  0.000000e+00      0         0  ...  5154          path  None     None
#
#        oneway maxspeed layer  bridge  tunnel  \
# 0           B        0     0       F       F
# 1           B        0     0       F       F
# 2           B        0     0       F       F
# 3           B        0     0       F       F
# 4           B        0     0       F       F
# ...       ...      ...   ...     ...     ...
# 122758      B        0     0       F       F
# 122759      B        0     0       F       F
# 122760      B        0     0       F       F
# 122761      B        0     0       F       F
# 122762      B        0     0       F       F
#
#                                                  geometry
# 0       LINESTRING (88.07218 27.18638, 88.07219 27.186...
# 1       LINESTRING (88.00206 27.10488, 88.00212 27.104...
# 2       MULTILINESTRING ((88.07824 27.14037, 88.07827 ...
# 3       MULTILINESTRING ((88.07175 27.13737, 88.07185 ...
# 4       MULTILINESTRING ((88.01190 27.15889, 88.01205 ...
# ...                                                   ...
# 122758  LINESTRING (88.26645 21.55965, 88.26645 21.559...
# 122759  LINESTRING (88.25075 21.56760, 88.25121 21.56829)
# 122760  LINESTRING (88.24892 21.56488, 88.25075 21.56760)
# 122761  LINESTRING (88.25401 21.57056, 88.25448 21.570...
# 122762  LINESTRING (88.97905 21.72634, 88.97895 21.72611)
#
# [122763 rows x 224 columns]

# %%
len(mx[mx.fclass == 'motorway'])
# Out:
# 38

# %%
mx[mx.fclass == 'motorway'].name.unique()
# Out:
# array([None, 'Vidyasagar Setu', 'Kona Expressway'], dtype=object)

# %%
len(mx) / 1e3
# Out:
# 122.763

# %%
mx.fclass.value_counts()
# Out:
# residential       31628
# unclassified      23816
# service           19703
# tertiary          15042
# secondary          5306
# primary            5006
# path               4611
# trunk              4551
# track              4066
# living_street      3857
# footway            2081
# unknown            1972
# steps               348
# trunk_link          141
# pedestrian          122
# cycleway            104
# secondary_link      100
# tertiary_link        94
# motorway_link        64
# primary_link         56
# motorway             38
# track_grade3         15
# track_grade2         13
# track_grade4         10
# track_grade1          9
# track_grade5          6
# bridleway             4
# Name: fclass, dtype: int64

# %%
mx[mx.name == 'Kona Expressway'].explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5cdba7d7a3ae8094218d14afe0156d8e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5cdba7d7a3ae8094218d14afe0156d8e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5cdba7d7a3ae8094218d14afe0156d8e = L.map(
#                 &quot;map_5cdba7d7a3ae8094218d14afe0156d8e&quot;,
#                 {
#                     center: [22.5848582, 88.28503624999999],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_5cdba7d7a3ae8094218d14afe0156d8e);
#
#
#
#
#
#             var tile_layer_197bd23ed1127c3c4e429e5ab291fdab = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_5cdba7d7a3ae8094218d14afe0156d8e);
#
#
#             map_5cdba7d7a3ae8094218d14afe0156d8e.fitBounds(
#                 [[22.5676324, 88.2608377], [22.602084, 88.3092348]],
#                 {}
#             );
#
#
#         function geo_json_b0860ae999aee814db09344303ced40a_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_b0860ae999aee814db09344303ced40a_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_b0860ae999aee814db09344303ced40a_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_b0860ae999aee814db09344303ced40a_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_b0860ae999aee814db09344303ced40a_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_b0860ae999aee814db09344303ced40a.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_b0860ae999aee814db09344303ced40a_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_b0860ae999aee814db09344303ced40a = L.geoJson(null, {
#                 onEachFeature: geo_json_b0860ae999aee814db09344303ced40a_onEachFeature,
#
#                 style: geo_json_b0860ae999aee814db09344303ced40a_styler,
#                 pointToLayer: geo_json_b0860ae999aee814db09344303ced40a_pointToLayer
#         });
#
#         function geo_json_b0860ae999aee814db09344303ced40a_add (data) {
#             geo_json_b0860ae999aee814db09344303ced40a
#                 .addData(data)
#                 .addTo(map_5cdba7d7a3ae8094218d14afe0156d8e);
#         }
#             geo_json_b0860ae999aee814db09344303ced40a_add({&quot;bbox&quot;: [88.2608377, 22.5676324, 88.3092348, 22.602084], &quot;features&quot;: [{&quot;bbox&quot;: [88.2938954, 22.5676324, 88.3092348, 22.5827363], &quot;geometry&quot;: {&quot;coordinates&quot;: [[88.3092348, 22.5676324], [88.3088217, 22.5677042], [88.3083289, 22.567845], [88.307891, 22.5680168], [88.307557, 22.568163], [88.307044, 22.568488], [88.306364, 22.569115], [88.305965, 22.569636], [88.3055027, 22.5703991], [88.304419, 22.572188], [88.3038685, 22.5730401], [88.303596, 22.573462], [88.302856, 22.574352], [88.3018059, 22.575369], [88.301662, 22.575513], [88.301001, 22.576365], [88.30018, 22.577308], [88.299155, 22.57877], [88.29865, 22.579365], [88.29

# %%
mx[mx.name == 'Vidyasagar Setu'].explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c0867c43b5f0469c563ffe1333bc8e21 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c0867c43b5f0469c563ffe1333bc8e21&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c0867c43b5f0469c563ffe1333bc8e21 = L.map(
#                 &quot;map_c0867c43b5f0469c563ffe1333bc8e21&quot;,
#                 {
#                     center: [22.55069225, 88.3288577],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_c0867c43b5f0469c563ffe1333bc8e21);
#
#
#
#
#
#             var tile_layer_20bd1f4aad4a34deba83f3c23681c42f = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c0867c43b5f0469c563ffe1333bc8e21);
#
#
#             map_c0867c43b5f0469c563ffe1333bc8e21.fitBounds(
#                 [[22.5422422, 88.3251291], [22.5591423, 88.3325863]],
#                 {}
#             );
#
#
#         function geo_json_cf0f6ca907b862ac26caeea3d828c55c_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_cf0f6ca907b862ac26caeea3d828c55c_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_cf0f6ca907b862ac26caeea3d828c55c_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_cf0f6ca907b862ac26caeea3d828c55c_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_cf0f6ca907b862ac26caeea3d828c55c_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_cf0f6ca907b862ac26caeea3d828c55c.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_cf0f6ca907b862ac26caeea3d828c55c_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_cf0f6ca907b862ac26caeea3d828c55c = L.geoJson(null, {
#                 onEachFeature: geo_json_cf0f6ca907b862ac26caeea3d828c55c_onEachFeature,
#
#                 style: geo_json_cf0f6ca907b862ac26caeea3d828c55c_styler,
#                 pointToLayer: geo_json_cf0f6ca907b862ac26caeea3d828c55c_pointToLayer
#         });
#
#         function geo_json_cf0f6ca907b862ac26caeea3d828c55c_add (data) {
#             geo_json_cf0f6ca907b862ac26caeea3d828c55c
#                 .addData(data)
#                 .addTo(map_c0867c43b5f0469c563ffe1333bc8e21);
#         }
#             geo_json_cf0f6ca907b862ac26caeea3d828c55c_add({&quot;bbox&quot;: [88.3251291, 22.5422422, 88.3325863, 22.5591423], &quot;features&quot;: [{&quot;bbox&quot;: [88.3251291, 22.557144713593793, 88.32757658497395, 22.559038], &quot;geometry&quot;: {&quot;coordinates&quot;: [[88.32757658497395, 22.557144713593793], [88.3251291, 22.559038]], &quot;type&quot;: &quot;LineString&quot;}, &quot;id&quot;: &quot;87917&quot;, &quot;properties&quot;: {&quot;AC_SOC&quot;: 0, &quot;ADLT_LT_CT&quot;: 0, &quot;ALL_DISP&quot;: 0, &quot;ALL_HOSP&quot;: 0, &quot;APP_FP&quot;: 0, &quot;APP_MR&quot;: 0, &quot;APP_NAVCAN&quot;: 0, &quot;APP_NAVRIV&quot;: 0, &quot;APP_NW&quot;: 0, &quot;APP_PR&quot;: 0, &quot;AREA&quot;: 0.0, &quot;AREA_NA_CU&quot

# %%
a = mx[(mx.fclass == 'motorway') ]

# %%
b =  a[a.name.isnull()]

# %%
b.NAME.unique()
# Out:
# array(['Pothia', 'Gadiatol', 'Haora', 'Kolkata', 'Nibra'], dtype=object)

# %%
b[b.NAME == 'Nibra'].explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_357009268449fa49a9c10b436eb5ba97 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_357009268449fa49a9c10b436eb5ba97&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_357009268449fa49a9c10b436eb5ba97 = L.map(
#                 &quot;map_357009268449fa49a9c10b436eb5ba97&quot;,
#                 {
#                     center: [22.60727815, 88.2614872],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_357009268449fa49a9c10b436eb5ba97);
#
#
#
#
#
#             var tile_layer_ef9ed5037ce3b035db239991bf3ff9f1 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_357009268449fa49a9c10b436eb5ba97);
#
#
#             map_357009268449fa49a9c10b436eb5ba97.fitBounds(
#                 [[22.6058608, 88.2589772], [22.6086955, 88.2639972]],
#                 {}
#             );
#
#
#         function geo_json_75f743916f742a17e81600994a02ff8d_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_75f743916f742a17e81600994a02ff8d_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_75f743916f742a17e81600994a02ff8d_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_75f743916f742a17e81600994a02ff8d_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_75f743916f742a17e81600994a02ff8d_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_75f743916f742a17e81600994a02ff8d.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_75f743916f742a17e81600994a02ff8d_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_75f743916f742a17e81600994a02ff8d = L.geoJson(null, {
#                 onEachFeature: geo_json_75f743916f742a17e81600994a02ff8d_onEachFeature,
#
#                 style: geo_json_75f743916f742a17e81600994a02ff8d_styler,
#                 pointToLayer: geo_json_75f743916f742a17e81600994a02ff8d_pointToLayer
#         });
#
#         function geo_json_75f743916f742a17e81600994a02ff8d_add (data) {
#             geo_json_75f743916f742a17e81600994a02ff8d
#                 .addData(data)
#                 .addTo(map_357009268449fa49a9c10b436eb5ba97);
#         }
#             geo_json_75f743916f742a17e81600994a02ff8d_add({&quot;bbox&quot;: [88.2589772, 22.6058608, 88.2639972, 22.6086955], &quot;features&quot;: [{&quot;bbox&quot;: [88.2589772, 22.6066584, 88.2639972, 22.6086955], &quot;geometry&quot;: {&quot;coordinates&quot;: [[88.2592022, 22.6066584], [88.2590652, 22.6070986], [88.2590012, 22.6074583], [88.2589772, 22.6077148], [88.2590664, 22.6080257], [88.2592345, 22.6083047], [88.2594589, 22.6084953], [88.2596959, 22.6086156], [88.2600156, 22.6086955], [88.2604322, 22.608657], [88.2607641, 22.6085041], [88.2613343, 22.6082328], [88.2619819, 22.6079583], [88.2622518, 22.6078971], [88.2625627, 22.6078574], [88.2628921, 22.6078623], [88.2631797, 22.6079152], [88.263817, 22.6080937], [88.2639
