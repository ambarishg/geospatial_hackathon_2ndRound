# %%
SHAPE_FILE_ROADS = '../input/roads_railways/gis_osm_roads_free_1.shp'
FILE2 = '../input/village_census/india-village-census-2001-AS.shp'

# %%
import geopandas as gpd

# %%
# %%time
plot_locations = gpd.read_file(SHAPE_FILE_ROADS)
# Out:
# Wall time: 6min 23s

# %%
len(plot_locations) /1e6
# Out:
# 2.111685

# %%
plot_locations.head()
# Out:
#     osm_id  code    fclass                    name   ref oneway  maxspeed  \
# 0  3187224  5115  tertiary                Sha Road  None      B         0
# 1  3191425  5115  tertiary                      U2  None      B         0
# 2  3191428  5115  tertiary  Transport Bustand Road  None      B         0
# 3  3191437  5115  tertiary           Housing Board  None      B         0
# 4  3194810  5115  tertiary             Market Road  None      B         0
#
#    layer bridge tunnel                                           geometry
# 0      0      F      F  LINESTRING (76.32194 10.30471, 76.32174 10.304...
# 1      0      F      F  LINESTRING (76.33476 10.30725, 76.33477 10.306...
# 2      0      F      F  LINESTRING (76.33261 10.29997, 76.33282 10.300...
# 3      0      F      F  LINESTRING (76.33261 10.29997, 76.33327 10.299...
# 4      0      F      F  LINESTRING (76.33898 10.30246, 76.33906 10.305...

# %%
plot_locations[plot_locations.code == 5154]
# Out:
#             osm_id  code fclass                  name   ref oneway  maxspeed  \
# 1848      22836390  5154   path                  None  None      B         0
# 2743      22843941  5154   path  Jethalal Parekh Road  None      B         0
# 2898      22846167  5154   path                  None  None      B         0
# 2916      22846331  5154   path                  None  None      B         0
# 5104      22871593  5154   path                  None  None      B         0
# ...            ...   ...    ...                   ...   ...    ...       ...
# 2111546  585164269  5154   path                  None  None      B         0
# 2111628  585204823  5154   path                  None  None      B         0
# 2111629  585204824  5154   path                  None  None      B         0
# 2111630  585204825  5154   path                  None  None      B         0
# 2111632  585204827  5154   path                  None  None      B         0
#
#          layer bridge tunnel  \
# 1848         0      F      F
# 2743         0      F      F
# 2898         0      F      F
# 2916         0      F      F
# 5104         0      F      F
# ...        ...    ...    ...
# 2111546      0      F      F
# 2111628      0      F      F
# 2111629      0      F      F
# 2111630      0      F      F
# 2111632      0      F      F
#
#                                                   geometry
# 1848     LINESTRING (77.70280 35.18310, 77.70950 35.200...
# 2743     LINESTRING (72.90661 19.08313, 72.90731 19.08349)
# 2898     LINESTRING (72.83072 18.91688, 72.83042 18.917...
# 2916     LINESTRING (72.83038 18.91418, 72.83029 18.914...
# 5104     LINESTRING (75.86216 30.85492, 75.86245 30.854...
# ...                                                    ...
# 2111546  LINESTRING (91.71659 26.12800, 91.71652 26.127...
# 2111628  LINESTRING (77.17720 32.30911, 77.17715 32.309...
# 2111629  LINESTRING (77.17733 32.30925, 77.17739 32.309...
# 2111630  LINESTRING (77.17678 32.30907, 77.17679 32.309...
# 2111632  LINESTRING (77.17743 32.30862, 77.17755 32.308...
#
# [38625 rows x 11 columns]

# %%
state = gpd.read_file(FILE2)

# %%
len(state)
# Out:
# 22521

# %%
state.head()
# Out:
#   SID DID   TID VILL_CODE          C_CODE01               NAME     UID  \
# 0  18  14  0001  01522200  1814000101522200  Kapawpathar Deori  261578
# 1  18  14  0001  01522000  1814000101522000         Lakhimijan  261579
# 2  18  14  0001  01525800  1814000101525800          Bodo Gaon  261580
# 3  18  14  0001  01521900  1814000101521900      Padum Pukhuri  261581
# 4  18  14  0001  01525700  1814000101525700       Makuri Bosti  261582
#
#      CENSUS_COD  STATE  DISTRICT  ...  TANK_IRR  RIVER_IRR  LAKE_IRR  W_FALL  \
# 0  1.814000e+15     18        14  ...         0        0.0         0       0
# 1  1.814000e+15     18        14  ...         0        0.0         0       0
# 2  1.814000e+15     18        14  ...         0        0.0         0       0
# 3  1.814000e+15     18        14  ...         0        0.0         0       0
# 4  1.814000e+15     18        14  ...         0        0.0         0       0
#
#   OTH_IRR TOT_IRR  UN_IRR  CULT_WASTE  AREA_NA_CU  \
# 0       0     0.0  193.02       99.00       94.00
# 1       0     0.0  296.51       10.04       18.85
# 2       0     0.0   19.00        5.00        6.00
# 3       0     0.0  227.29       12.04       73.12
# 4       0     0.0   12.17        8.50        4.33
#
#                                             geometry
# 0  POLYGON ((1964160.999 3183920.364, 1964246.469...
# 1  POLYGON ((1961813.379 3183424.622, 1962657.119...
# 2  POLYGON ((1971594.216 3184599.663, 1971688.685...
# 3  POLYGON ((1956204.785 3182130.877, 1957240.796...
# 4  POLYGON ((1978033.791 3185175.334, 1978640.004...
#
# [5 rows x 214 columns]

# %%
motorway = plot_locations[plot_locations.fclass == 'motorway']

# %%
len(motorway)
# Out:
# 2544

# %%
x = plot_locations.to_crs(epsg='4326')
y = state.to_crs(epsg='4326')

# %%
mx = y.overlay(x,how="intersection",keep_geom_type=False)

# %%
mx.to_file('roads_assam.shp')

# %%
len(mx)
# Out:
# 34035

# %%
len(mx[mx.fclass == 'motorway'])
# Out:
# 0

# %%
mx[mx.fclass == 'motorway'].name.unique()
# Out:
# array([None, 'Vidyasagar Setu', 'Kona Expressway'], dtype=object)

# %%
len(mx) / 1e3
# Out:
# 122.763

# %%
mx.fclass.value_counts()
# Out:
# residential       31628
# unclassified      23816
# service           19703
# tertiary          15042
# secondary          5306
# primary            5006
# path               4611
# trunk              4551
# track              4066
# living_street      3857
# footway            2081
# unknown            1972
# steps               348
# trunk_link          141
# pedestrian          122
# cycleway            104
# secondary_link      100
# tertiary_link        94
# motorway_link        64
# primary_link         56
# motorway             38
# track_grade3         15
# track_grade2         13
# track_grade4         10
# track_grade1          9
# track_grade5          6
# bridleway             4
# Name: fclass, dtype: int64

# %%
mx[mx.name == 'Kona Expressway'].explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6fc78551b981ac82a0644c606fc28b25 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6fc78551b981ac82a0644c606fc28b25&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6fc78551b981ac82a0644c606fc28b25 = L.map(
#                 &quot;map_6fc78551b981ac82a0644c606fc28b25&quot;,
#                 {
#                     center: [22.5848582, 88.28503624999999],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_6fc78551b981ac82a0644c606fc28b25);
#
#
#
#
#
#             var tile_layer_e09368d0f9ecbfe2c7d79f9f1488bffb = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_6fc78551b981ac82a0644c606fc28b25);
#
#
#             map_6fc78551b981ac82a0644c606fc28b25.fitBounds(
#                 [[22.5676324, 88.2608377], [22.602084, 88.3092348]],
#                 {}
#             );
#
#
#         function geo_json_99512201d1deca864db8be5c027f0479_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_99512201d1deca864db8be5c027f0479_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_99512201d1deca864db8be5c027f0479_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_99512201d1deca864db8be5c027f0479_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_99512201d1deca864db8be5c027f0479_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_99512201d1deca864db8be5c027f0479.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_99512201d1deca864db8be5c027f0479_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_99512201d1deca864db8be5c027f0479 = L.geoJson(null, {
#                 onEachFeature: geo_json_99512201d1deca864db8be5c027f0479_onEachFeature,
#
#                 style: geo_json_99512201d1deca864db8be5c027f0479_styler,
#                 pointToLayer: geo_json_99512201d1deca864db8be5c027f0479_pointToLayer
#         });
#
#         function geo_json_99512201d1deca864db8be5c027f0479_add (data) {
#             geo_json_99512201d1deca864db8be5c027f0479
#                 .addData(data)
#                 .addTo(map_6fc78551b981ac82a0644c606fc28b25);
#         }
#             geo_json_99512201d1deca864db8be5c027f0479_add({&quot;bbox&quot;: [88.2608377, 22.5676324, 88.3092348, 22.602084], &quot;features&quot;: [{&quot;bbox&quot;: [88.2938954, 22.5676324, 88.3092348, 22.5827363], &quot;geometry&quot;: {&quot;coordinates&quot;: [[88.3092348, 22.5676324], [88.3088217, 22.5677042], [88.3083289, 22.567845], [88.307891, 22.5680168], [88.307557, 22.568163], [88.307044, 22.568488], [88.306364, 22.569115], [88.305965, 22.569636], [88.3055027, 22.5703991], [88.304419, 22.572188], [88.3038685, 22.5730401], [88.303596, 22.573462], [88.302856, 22.574352], [88.3018059, 22.575369], [88.301662, 22.575513], [88.301001, 22.576365], [88.30018, 22.577308], [88.299155, 22.57877], [88.29865, 22.579365], [88.29

# %%
mx[mx.name == 'Vidyasagar Setu'].explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c3783062fbc4dd8fcb044d54b201e6dc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c3783062fbc4dd8fcb044d54b201e6dc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c3783062fbc4dd8fcb044d54b201e6dc = L.map(
#                 &quot;map_c3783062fbc4dd8fcb044d54b201e6dc&quot;,
#                 {
#                     center: [22.55069225, 88.3288577],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_c3783062fbc4dd8fcb044d54b201e6dc);
#
#
#
#
#
#             var tile_layer_32b57cc9d94b91f9962ef9ee030e56bb = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c3783062fbc4dd8fcb044d54b201e6dc);
#
#
#             map_c3783062fbc4dd8fcb044d54b201e6dc.fitBounds(
#                 [[22.5422422, 88.3251291], [22.5591423, 88.3325863]],
#                 {}
#             );
#
#
#         function geo_json_eb3c57919270141d4595d901b34b6f68_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_eb3c57919270141d4595d901b34b6f68_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_eb3c57919270141d4595d901b34b6f68_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_eb3c57919270141d4595d901b34b6f68_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_eb3c57919270141d4595d901b34b6f68_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_eb3c57919270141d4595d901b34b6f68.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_eb3c57919270141d4595d901b34b6f68_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_eb3c57919270141d4595d901b34b6f68 = L.geoJson(null, {
#                 onEachFeature: geo_json_eb3c57919270141d4595d901b34b6f68_onEachFeature,
#
#                 style: geo_json_eb3c57919270141d4595d901b34b6f68_styler,
#                 pointToLayer: geo_json_eb3c57919270141d4595d901b34b6f68_pointToLayer
#         });
#
#         function geo_json_eb3c57919270141d4595d901b34b6f68_add (data) {
#             geo_json_eb3c57919270141d4595d901b34b6f68
#                 .addData(data)
#                 .addTo(map_c3783062fbc4dd8fcb044d54b201e6dc);
#         }
#             geo_json_eb3c57919270141d4595d901b34b6f68_add({&quot;bbox&quot;: [88.3251291, 22.5422422, 88.3325863, 22.5591423], &quot;features&quot;: [{&quot;bbox&quot;: [88.3251291, 22.557144713593793, 88.32757658497395, 22.559038], &quot;geometry&quot;: {&quot;coordinates&quot;: [[88.32757658497395, 22.557144713593793], [88.3251291, 22.559038]], &quot;type&quot;: &quot;LineString&quot;}, &quot;id&quot;: &quot;87917&quot;, &quot;properties&quot;: {&quot;AC_SOC&quot;: 0, &quot;ADLT_LT_CT&quot;: 0, &quot;ALL_DISP&quot;: 0, &quot;ALL_HOSP&quot;: 0, &quot;APP_FP&quot;: 0, &quot;APP_MR&quot;: 0, &quot;APP_NAVCAN&quot;: 0, &quot;APP_NAVRIV&quot;: 0, &quot;APP_NW&quot;: 0, &quot;APP_PR&quot;: 0, &quot;AREA&quot;: 0.0, &quot;AREA_NA_CU&quot

# %%
a = mx[(mx.fclass == 'motorway') ]

# %%
b =  a[a.name.isnull()]

# %%
b.NAME.unique()
# Out:
# array(['Pothia', 'Gadiatol', 'Haora', 'Kolkata', 'Nibra'], dtype=object)

# %%
b[b.NAME == 'Nibra'].explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_87631471337447375e9c3928164a09ab {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_87631471337447375e9c3928164a09ab&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_87631471337447375e9c3928164a09ab = L.map(
#                 &quot;map_87631471337447375e9c3928164a09ab&quot;,
#                 {
#                     center: [22.60727815, 88.2614872],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_87631471337447375e9c3928164a09ab);
#
#
#
#
#
#             var tile_layer_948aba6010f9323f1cc8c54f3f3ee318 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_87631471337447375e9c3928164a09ab);
#
#
#             map_87631471337447375e9c3928164a09ab.fitBounds(
#                 [[22.6058608, 88.2589772], [22.6086955, 88.2639972]],
#                 {}
#             );
#
#
#         function geo_json_a9369290e267ed229ffc4c982c78dc28_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_a9369290e267ed229ffc4c982c78dc28_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_a9369290e267ed229ffc4c982c78dc28_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_a9369290e267ed229ffc4c982c78dc28_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_a9369290e267ed229ffc4c982c78dc28_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_a9369290e267ed229ffc4c982c78dc28.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_a9369290e267ed229ffc4c982c78dc28_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_a9369290e267ed229ffc4c982c78dc28 = L.geoJson(null, {
#                 onEachFeature: geo_json_a9369290e267ed229ffc4c982c78dc28_onEachFeature,
#
#                 style: geo_json_a9369290e267ed229ffc4c982c78dc28_styler,
#                 pointToLayer: geo_json_a9369290e267ed229ffc4c982c78dc28_pointToLayer
#         });
#
#         function geo_json_a9369290e267ed229ffc4c982c78dc28_add (data) {
#             geo_json_a9369290e267ed229ffc4c982c78dc28
#                 .addData(data)
#                 .addTo(map_87631471337447375e9c3928164a09ab);
#         }
#             geo_json_a9369290e267ed229ffc4c982c78dc28_add({&quot;bbox&quot;: [88.2589772, 22.6058608, 88.2639972, 22.6086955], &quot;features&quot;: [{&quot;bbox&quot;: [88.2589772, 22.6066584, 88.2639972, 22.6086955], &quot;geometry&quot;: {&quot;coordinates&quot;: [[88.2592022, 22.6066584], [88.2590652, 22.6070986], [88.2590012, 22.6074583], [88.2589772, 22.6077148], [88.2590664, 22.6080257], [88.2592345, 22.6083047], [88.2594589, 22.6084953], [88.2596959, 22.6086156], [88.2600156, 22.6086955], [88.2604322, 22.608657], [88.2607641, 22.6085041], [88.2613343, 22.6082328], [88.2619819, 22.6079583], [88.2622518, 22.6078971], [88.2625627, 22.6078574], [88.2628921, 22.6078623], [88.2631797, 22.6079152], [88.263817, 22.6080937], [88.2639
