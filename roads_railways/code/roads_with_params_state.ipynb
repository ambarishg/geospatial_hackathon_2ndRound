# %%
import papermill as pm

# %%
SHAPE_FILE_ROADS = '../input/roads_railways/gis_osm_roads_free_1.shp'
FILE2 = '../input/village_census/india-village-census-2001-UP.shp'
FILE_OUTPUT = 'roads_up_02.shp'

pm.execute_notebook(
   'roads_overlay_parameters.ipynb',
   'roads_up_parameters.ipynb',
   parameters=dict(SHAPE_FILE_ROADS=SHAPE_FILE_ROADS, FILE2=FILE2,FILE_OUTPUT=FILE_OUTPUT)
)
# Out:
# Executing:   0%|          | 0/15 [00:00<?, ?cell/s]
# {'cells': [{'cell_type': 'code',
#    'execution_count': 1,
#    'id': '18942a72',
#    'metadata': {'tags': ['parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2023-03-15T12:21:43.342622',
#      'end_time': '2023-03-15T12:21:43.375407',
#      'duration': 0.032785,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2023-03-15T12:21:43.353677Z',
#      'iopub.execute_input': '2023-03-15T12:21:43.354643Z',
#      'iopub.status.idle': '2023-03-15T12:21:43.371184Z',
#      'shell.execute_reply': '2023-03-15T12:21:43.371184Z'}},
#    'outputs': [],
#    'source': "SHAPE_FILE_ROADS = '../input/roads_railways/gis_osm_roads_free_1.shp'\nFILE2 = '../input/village_census/india-village-census-2001-AS.shp'\nFILE_OUTPUT = 'roads_assam_01.shp'"},
#   {'id': '71ba4dea',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
# ...

# %%
SHAPE_FILE_ROADS = '../input/roads_railways/gis_osm_roads_free_1.shp'
FILE2 = '../input/village_census/india-village-census-2001-AS.shp'
FILE_OUTPUT = 'roads_assam_02.shp'

pm.execute_notebook(
   'roads_overlay_parameters.ipynb',
   'roads_assam_parameters.ipynb',
   parameters=dict(SHAPE_FILE_ROADS=SHAPE_FILE_ROADS, FILE2=FILE2,FILE_OUTPUT=FILE_OUTPUT)
)

# %%
FILE2 = 'roads_wb.shp'

pm.execute_notebook(
   'roads_analysis_parameters.ipynb',
   'roads_wb_analysis.ipynb',
   parameters=dict(FILE2=FILE2)
)
# Out:
# Executing:   0%|          | 0/17 [00:00<?, ?cell/s]
# {'cells': [{'cell_type': 'code',
#    'execution_count': 1,
#    'id': '926a7f2e',
#    'metadata': {'tags': ['parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2023-03-15T14:17:29.583599',
#      'end_time': '2023-03-15T14:17:29.618775',
#      'duration': 0.035176,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2023-03-15T14:17:29.592391Z',
#      'iopub.execute_input': '2023-03-15T14:17:29.593389Z',
#      'shell.execute_reply': '2023-03-15T14:17:29.613886Z',
#      'iopub.status.idle': '2023-03-15T14:17:29.615665Z'}},
#    'outputs': [],
#    'source': "FILE2 = 'roads_up_02.shp'"},
#   {'id': '4bc58e9c',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2023-03-15T14:17:29.628699',
#      'end_time': '2023-03-15T14:17:29.649887',
#      'duration': 0.021188,
# ...
