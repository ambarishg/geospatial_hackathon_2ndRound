# %%
import geopandas as gpd

# %%
FILE2 = 'roads_wb.shp'

# %%
# %%time
plot_locations = gpd.read_file(FILE2)
# Out:
# Wall time: 1min 12s

# %%
len(plot_locations) /1e3
# Out:
# 122.763

# %%
mw = plot_locations[plot_locations.fclass == 'motorway']

# %%
mw.name_2.value_counts()
# Out:
# Kona Expressway    13
# Vidyasagar Setu     9
# Name: name_2, dtype: int64

# %%
mw[mw.name_2 == 'Kona Expressway'].explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
mw[mw.name_2 == 'Kona Expressway'].NAME.unique()
# Out:
# array(['Haora', 'Nibra'], dtype=object)

# %%
b =  mw[mw.name_2.isnull()]

# %%
b
# Out:
#        SID DID   TID VILL_CODE          C_CODE01      NAME     UID  \
# 29682   19  04  0002  00281400  1904000200281400    Pothia  286563
# 29697   19  04  0002  00281400  1904000200281400    Pothia  286563
# 29698   19  04  0002  00281500  1904000200281500  Gadiatol  286568
# 29699   19  04  0002  00281400  1904000200281400    Pothia  286563
# 29700   19  04  0002  00281400  1904000200281400    Pothia  286563
# 29701   19  04  0002  00281500  1904000200281500  Gadiatol  286568
# 87921   19  16  0015  41626000  1916001541626000     Haora  312210
# 87935   19  16  0015  41626000  1916001541626000     Haora  312210
# 88249   19  16  0015  41626000  1916001541626000     Haora  312210
# 88629   19  16  0015  41626000  1916001541626000     Haora  312210
# 88630   19  16  0015  41626000  1916001541626000     Haora  312210
# 88633   19  16  0015  41626000  1916001541626000     Haora  312210
# 88634   19  16  0015  41626000  1916001541626000     Haora  312210
# ...

# %%
mw[mw.name_2 == 'Vidyasagar Setu'].explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
b[b.ref == 'NH12'].explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...
